# %%
# test_query.py
from pinecone import Pinecone
import os
from dotenv import load_dotenv
from langchain_aws import BedrockEmbeddings

load_dotenv()
PINECONE_API_KEY = os.environ.get("PINECONE_API_KEY")
INDEX_NAME = os.environ.get("PINECONE_INDEX_NAME", "trailblazeai")
AWS_REGION = os.environ.get("AWS_REGION", "us-east-1")
BEDROCK_EMBED_MODEL = os.environ.get("BEDROCK_EMBED_MODEL", "amazon.titan-embed-text-v1")

# Connect Pinecone
pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index(INDEX_NAME)

# Prepare embedding
embed_fn = BedrockEmbeddings(model_id=BEDROCK_EMBED_MODEL, region_name=AWS_REGION)
query_text = "financial performance last year"
query_vector = embed_fn.embed_query(query_text)

# Query top 5 relevant chunks
response = index.query(
    vector=query_vector,
    top_k=5,
    include_values=False,
    include_metadata=True
)

print("Top matches:")
for i, match in enumerate(response["matches"], 1):
    print(f"Match {i}:")
    print("Metadata:", match.get("metadata"))
    print("-" * 50)
# Out:
# Top matches:
# Match 1:
# Metadata: {'category': 'wealth', 'source': '/home/sagemaker-user/TrailblazeAI/data/wealth/financial_reports/.ipynb_checkpoints/Starbucks_2025_annual_statement-checkpoint.pdf', 'subcategory': 'financial_reports'}
# --------------------------------------------------
# Match 2:
# Metadata: {'category': 'wealth', 'source': '/home/sagemaker-user/TrailblazeAI/data/wealth/financial_reports/Starbucks_2025_annual_statement.pdf', 'subcategory': 'financial_reports'}
# --------------------------------------------------
# Match 3:
# Metadata: {'category': 'wealth', 'source': '/home/sagemaker-user/TrailblazeAI/data/wealth/financial_reports/.ipynb_checkpoints/Starbucks_2025_annual_statement-checkpoint.pdf', 'subcategory': 'financial_reports'}
# --------------------------------------------------
# Match 4:
# Metadata: {'category': 'wealth', 'source': '/home/sagemaker-user/TrailblazeAI/data/wealth/financial_reports/Starbucks_2025_annual_statement.pdf', 'subcategory': 'financial_reports'}
# --------------------------------------------------
# Match 5:
# Metadata: {'category': 'wealth', 'source': '/home/sagemaker-user/TrailblazeAI/data/wealth/financial_reports/.ipynb_checkpoints/Starbucks_2025_annual_statement-checkpoint.pdf', 'subcategory': 'financial_reports'}
# --------------------------------------------------

# %%
PINECONE_API_KEY
# Out:
# 'pcsk_n65UB_9sJyHhBoDkAFV8azk45qjgNFdufDXGCzjUuE37VRGtenARFNyLKHJ7jcdVY5yNN'
